# %%
Plot[Sin[x],{x,-Pi,Pi},PlotRange->{-1,1},Frame->True]
# Out:
# -Graphics-

# %%
stance1={{0,-1,-1,1,1}(*all vs. H*),
{1,0,-1,-1,1}(*all vs. F*),
{1,1,0,-1,-1}(*all vs. R*),
{-1,1,1,0,-1}(*all vs. A*),
{-1,-1,1,1,0}(*all vs. L*)};
oponent1={1,2,5};(*1->H,2->F,3->R,4->A,5->L*)
winindex1=Sum[stance1[[n,#]],{n,oponent1}]&/@{1,2,3,4,5}
Lookup[Max[winindex1]]@Association[{winindex1[[#]]->#}]&/@{1,2,3,4,5}
# Out:
# {0, -2, -1, 1, 2}
# {Missing[KeyAbsent, 2], Missing[KeyAbsent, 2], Missing[KeyAbsent, 2],
#
# >   Missing[KeyAbsent, 2], 5}

# %%
# Out:
# CurrentDictionary[]
